# %% [markdown]
# <a href="https://colab.research.google.com/github/eji58/Python-Core/blob/main/Exception_Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exception type names:
#
# 1. ImportError
# 2. IndexError
# 3. NameError
# 4. SyntaxError
# 5. TypeError
# 6. ValueError

# %% [markdown]
# ### ImportError
# is raised when a module, or member of a module, cannot be imported. There are a two conditions where an ImportError might be raised. If a module does not exist.

# %%
import name_module

# %% [markdown]
# ### IndexError

# %%
a=[1,2,3]
a[3]

# %% [markdown]
# ### NameError

# %%
y

# %% [markdown]
# ### SyntaxError

# %%
if 1==1
print(1)

# %% [markdown]
# ### TypeError

# %%
print(1+"a")

# %% [markdown]
# ### ValueError

# %%
a="a"
n =int(a)

# %%
print(1/0)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
try:
  print(1/0)
except:
  print("not allow to division by zero")

# %%
try:
  print(1/0)
except:
  print("not allow to division by zero")
else:
  print("this will execute when either the try execute")

# %%
try:
  print(1/1)
except:
  print("not allow to division by zero")
else:
  print("this will execute just when the try execute")

# %%
try:
  print(1/1)
except:
  print("not allow to division by zero")
finally:
  print("this will execute when either the try or except execute")

# %%
try:
  print(1/0)
except:
  print("not allow to division by zero")
finally:
  print("this will execute when either the try or except execute")

# %% [markdown]
# # raise
# to determine the type of the exception with message

# %%
try:
  print(1/0)
except:
  raise ValueError("not allow to division by zero")

# %%
a = "123"
raise NameError("Invalid Name")
